# %%
import numpy as np
import pandas as pd

# %%
links=pd.read_csv('links.csv')
movies=pd.read_csv('movies.csv')
ratings=pd.read_csv('ratings.csv')
tags=pd.read_csv('tags.csv')

# %%
links
# Out:
#       movieId   imdbId    tmdbId
# 0           1   114709     862.0
# 1           2   113497    8844.0
# 2           3   113228   15602.0
# 3           4   114885   31357.0
# 4           5   113041   11862.0
# ...       ...      ...       ...
# 9737   193581  5476944  432131.0
# 9738   193583  5914996  445030.0
# 9739   193585  6397426  479308.0
# 9740   193587  8391976  483455.0
# 9741   193609   101726   37891.0
#
# [9742 rows x 3 columns]

# %%
movies
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %%
ratings
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
tags
# Out:
#       userId  movieId               tag   timestamp
# 0          2    60756             funny  1445714994
# 1          2    60756   Highly quotable  1445714996
# 2          2    60756      will ferrell  1445714992
# 3          2    89774      Boxing story  1445715207
# 4          2    89774               MMA  1445715200
# ...      ...      ...               ...         ...
# 3678     606     7382         for katie  1171234019
# 3679     606     7936           austere  1173392334
# 3680     610     3265            gun fu  1493843984
# 3681     610     3265  heroic bloodshed  1493843978
# 3682     610   168248  Heroic Bloodshed  1493844270
#
# [3683 rows x 4 columns]

# %%
movies.shape
# Out:
# (9742, 3)

# %%
ratings.shape
# Out:
# (100836, 4)

# %%
len(ratings['userId'].unique())
# Out:
# 610

# %%
ratings
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
ratings.sort_values(by='rating',ascending=False)
# Out:
#        userId  movieId  rating   timestamp
# 34031     232     3147     5.0  1218164903
# 50717     328     1080     5.0  1494210450
# 18166     115      487     5.0   944951378
# 18165     115      480     5.0   944953733
# 76157     479     3308     5.0  1039362558
# ...       ...      ...     ...         ...
# 99278     608     4679     0.5  1117506642
# 99277     608     4678     0.5  1117506202
# 95668     600     4744     0.5  1237714406
# 99269     608     4621     0.5  1117506916
# 78499     489      168     0.5  1332774713
#
# [100836 rows x 4 columns]

# %%
ratings[ratings['rating']==5]
# Out:
#         userId  movieId  rating           timestamp
# 3            1       47     5.0 2000-07-30 19:03:35
# 4            1       50     5.0 2000-07-30 18:48:51
# 6            1      101     5.0 2000-07-30 18:14:28
# 8            1      151     5.0 2000-07-30 19:07:21
# 9            1      157     5.0 2000-07-30 19:08:20
# ...        ...      ...     ...                 ...
# 100814     610   158238     5.0 2016-11-19 08:46:59
# 100829     610   164179     5.0 2017-05-03 21:07:11
# 100832     610   168248     5.0 2017-05-03 22:21:31
# 100833     610   168250     5.0 2017-05-08 19:50:47
# 100834     610   168252     5.0 2017-05-03 21:19:12
#
# [13211 rows x 4 columns]

# %%
ratings['timestamp']=pd.to_datetime(ratings['timestamp'],unit='s')

# %%
ratings
# Out:
#         userId  movieId  rating           timestamp
# 0            1        1     4.0 2000-07-30 18:45:03
# 1            1        3     4.0 2000-07-30 18:20:47
# 2            1        6     4.0 2000-07-30 18:37:04
# 3            1       47     5.0 2000-07-30 19:03:35
# 4            1       50     5.0 2000-07-30 18:48:51
# ...        ...      ...     ...                 ...
# 100831     610   166534     4.0 2017-05-03 21:53:22
# 100832     610   168248     5.0 2017-05-03 22:21:31
# 100833     610   168250     5.0 2017-05-08 19:50:47
# 100834     610   168252     5.0 2017-05-03 21:19:12
# 100835     610   170875     3.0 2017-05-03 21:20:15
#
# [100836 rows x 4 columns]

# %%
movies
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %%
combined=pd.merge(movies,ratings,on='movieId')
combined
# Out:
#         movieId                                      title  \
# 0             1                           Toy Story (1995)
# 1             1                           Toy Story (1995)
# 2             1                           Toy Story (1995)
# 3             1                           Toy Story (1995)
# 4             1                           Toy Story (1995)
# ...         ...                                        ...
# 100831   193581  Black Butler: Book of the Atlantic (2017)
# 100832   193583               No Game No Life: Zero (2017)
# 100833   193585                               Flint (2017)
# 100834   193587        Bungo Stray Dogs: Dead Apple (2018)
# 100835   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                              genres  userId  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy       1     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy       5     4.0
# ...

# %%
combined[(combined['title'].str.contains('Matrix')) & (combined['rating']==5)]
# Out:
#        movieId                           title  \
# 45014     2571              Matrix, The (1999)
# 45017     2571              Matrix, The (1999)
# 45020     2571              Matrix, The (1999)
# 45025     2571              Matrix, The (1999)
# 45027     2571              Matrix, The (1999)
# ...        ...                             ...
# 72886     6934  Matrix Revolutions, The (2003)
# 72887     6934  Matrix Revolutions, The (2003)
# 72900     6934  Matrix Revolutions, The (2003)
# 72926     6934  Matrix Revolutions, The (2003)
# 72931     6934  Matrix Revolutions, The (2003)
#
#                                       genres  userId  rating   timestamp
# 45014                 Action|Sci-Fi|Thriller       1     5.0   964981888
# 45017                 Action|Sci-Fi|Thriller      13     5.0   987457007
# 45020                 Action|Sci-Fi|Thriller      17     5.0  1305696756
# 45025                 Action|Sci-Fi|Thriller      25     5.0  1535470427
# ...

# %%
combined[combined['title'].str.contains('Shawshank')].count()
# Out:
# movieId      317
# title        317
# genres       317
# userId       317
# rating       317
# timestamp    317
# dtype: int64

# %%
#Select all the correct tags submitted by users to "Matrix,The(1999)"

# %%
tags
# Out:
#       userId  movieId               tag   timestamp
# 0          2    60756             funny  1445714994
# 1          2    60756   Highly quotable  1445714996
# 2          2    60756      will ferrell  1445714992
# 3          2    89774      Boxing story  1445715207
# 4          2    89774               MMA  1445715200
# ...      ...      ...               ...         ...
# 3678     606     7382         for katie  1171234019
# 3679     606     7936           austere  1173392334
# 3680     610     3265            gun fu  1493843984
# 3681     610     3265  heroic bloodshed  1493843978
# 3682     610   168248  Heroic Bloodshed  1493844270
#
# [3683 rows x 4 columns]

# %%
combined_2=pd.merge(combined,tags,on='movieId')

# %%
combined_2[(combined_2['title']=='Matrix, The (1999)') & (combined_2['tag'])]['tag'].unique
# Out:
# <bound method Series.unique of 142140          martial arts
# 142141                sci-fi
# 142142    alternate universe
# 142143            philosophy
# 142144      post apocalyptic
#                  ...
# 143525          martial arts
# 143526                sci-fi
# 143527    alternate universe
# 143528            philosophy
# 143529      post apocalyptic
# Name: tag, Length: 1390, dtype: object>

# %%
# average user ratings for the movie named " Terminator 2:Judgement Day(1991) "

# %%
combined_2[combined_2['title'].str.contains('Terminator')]
# Out:
#         movieId                              title  \
# 93035       589  Terminator 2: Judgment Day (1991)
# 93036       589  Terminator 2: Judgment Day (1991)
# 93037       589  Terminator 2: Judgment Day (1991)
# 93038       589  Terminator 2: Judgment Day (1991)
# 93039       589  Terminator 2: Judgment Day (1991)
# ...         ...                                ...
# 214055    68791        Terminator Salvation (2009)
# 214056    68791        Terminator Salvation (2009)
# 214057    68791        Terminator Salvation (2009)
# 214058    68791        Terminator Salvation (2009)
# 214059    68791        Terminator Salvation (2009)
#
#                                   genres  userId_x  rating  timestamp_x  \
# 93035                      Action|Sci-Fi         5     3.0    847435258
# 93036                      Action|Sci-Fi         5     3.0    847435258
# 93037                      Action|Sci-Fi         5     3.0    847435258
# ...

# %%
combined_2[combined_2['title']=='Terminator 2: Judgment Day (1991)']
# Out:
#        movieId                              title         genres  userId_x  \
# 93035      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi         5
# 93036      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi         5
# 93037      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi         5
# 93038      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi         5
# 93039      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi         5
# ...        ...                                ...            ...       ...
# 94822      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi       610
# 94823      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi       610
# 94824      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi       610
# 94825      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi       610
# 94826      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi       610
#
# ...

# %%
x=combined_2['rating'].mean()

# %%
x
# Out:
# 3.9665348844189645

# %%
# How does the data distribution of user ratings for "Fight Club (1999)" movie looks like?

# %%
combined_2[(combined_2['title'].str.contains("Fight Club")) & (combined_2['rating']==4)]
# Out:
#         movieId              title                       genres  userId_x  \
# 149476     2959  Fight Club (1999)  Action|Crime|Drama|Thriller        34
# 149477     2959  Fight Club (1999)  Action|Crime|Drama|Thriller        34
# 149478     2959  Fight Club (1999)  Action|Crime|Drama|Thriller        34
# 149479     2959  Fight Club (1999)  Action|Crime|Drama|Thriller        34
# 149480     2959  Fight Club (1999)  Action|Crime|Drama|Thriller        34
# ...         ...                ...                          ...       ...
# 160487     2959  Fight Club (1999)  Action|Crime|Drama|Thriller       603
# 160488     2959  Fight Club (1999)  Action|Crime|Drama|Thriller       603
# 160489     2959  Fight Club (1999)  Action|Crime|Drama|Thriller       603
# 160490     2959  Fight Club (1999)  Action|Crime|Drama|Thriller       603
# 160491     2959  Fight Club (1999)  Action|Crime|Drama|Thriller       603
#
#         rating  timestamp_x  userId_y                tag  timestamp_y
# ...

# %%
combined_2
# Out:
#         movieId                           title  \
# 0             1                Toy Story (1995)
# 1             1                Toy Story (1995)
# 2             1                Toy Story (1995)
# 3             1                Toy Story (1995)
# 4             1                Toy Story (1995)
# ...         ...                             ...
# 233208   187595  Solo: A Star Wars Story (2018)
# 233209   193565       Gintama: The Movie (2010)
# 233210   193565       Gintama: The Movie (2010)
# 233211   193565       Gintama: The Movie (2010)
# 233212   193565       Gintama: The Movie (2010)
#
#                                              genres  userId_x  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy         1     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy         1     4.0
# 2       Adventure|Animation|Children|Comedy|Fantasy         1     4.0
# 3       Adventure|Animation|Children|Comedy|Fantasy         5     4.0
# ...

# %%
x=combined_2.groupby('title')['rating'].mean()

# %%
x
# Out:
# title
# (500) Days of Summer (2009)          3.666667
# ...And Justice for All (1979)        3.166667
# 10 Cloverfield Lane (2016)           3.678571
# 10 Things I Hate About You (1999)    3.527778
# 101 Dalmatians (1996)                3.074468
#                                        ...
# Zero Dark Thirty (2012)              4.107143
# Zombieland (2009)                    3.877358
# Zoolander (2001)                     3.509259
# Zulu (1964)                          4.000000
# eXistenZ (1999)                      3.863636
# Name: rating, Length: 1554, dtype: float64

# %%
z=pd.DataFrame(x)

# %%
z
# Out:
#                                      rating
# title
# (500) Days of Summer (2009)        3.666667
# ...And Justice for All (1979)      3.166667
# 10 Cloverfield Lane (2016)         3.678571
# 10 Things I Hate About You (1999)  3.527778
# 101 Dalmatians (1996)              3.074468
# ...                                     ...
# Zero Dark Thirty (2012)            4.107143
# Zombieland (2009)                  3.877358
# Zoolander (2001)                   3.509259
# Zulu (1964)                        4.000000
# eXistenZ (1999)                    3.863636
#
# [1554 rows x 1 columns]

# %%
z.sort_values(by='rating',ascending=False)
# Out:
#                                        rating
# title
# Come and See (Idi i smotri) (1985)   5.000000
# Lady Jane (1986)                     5.000000
# Woman Under the Influence, A (1974)  5.000000
# Into the Woods (1991)                5.000000
# Two Family House (2000)              5.000000
# ...                                       ...
# Oh, God! Book II (1980)              1.500000
# Jaws 3-D (1983)                      1.416667
# Losin' It (1983)                     1.000000
# My Demon Lover (1987)                1.000000
# Begotten (1990)                      0.500000
#
# [1554 rows x 1 columns]

# %%
z.loc['Godfather, The (1972)','rating']
# Out:
# 4.2890625

# %%
z.loc['Shawshank Redemption, The (1994)','rating']
# Out:
# 4.429022082018927

# %%
z.loc['Jumanji (1995)','rating']
# Out:
# 3.4318181818181817

# %%
z.loc['Wolf of Wall Street, The (2013)','rating']
# Out:
# 3.9166666666666665

# %%
# Select all the correct options which comes under top 5 popular movies based on number of user ratings.

# %%
combined_2
# Out:
#         movieId                           title  \
# 0             1                Toy Story (1995)
# 1             1                Toy Story (1995)
# 2             1                Toy Story (1995)
# 3             1                Toy Story (1995)
# 4             1                Toy Story (1995)
# ...         ...                             ...
# 233208   187595  Solo: A Star Wars Story (2018)
# 233209   193565       Gintama: The Movie (2010)
# 233210   193565       Gintama: The Movie (2010)
# 233211   193565       Gintama: The Movie (2010)
# 233212   193565       Gintama: The Movie (2010)
#
#                                              genres  userId_x  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy         1     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy         1     4.0
# 2       Adventure|Animation|Children|Comedy|Fantasy         1     4.0
# 3       Adventure|Animation|Children|Comedy|Fantasy         5     4.0
# ...

# %%
x=combined_2.groupby('title')['rating'].sum()

# %%
x
# Out:
# title
# (500) Days of Summer (2009)          1232.0
# ...And Justice for All (1979)           9.5
# 10 Cloverfield Lane (2016)            103.0
# 10 Things I Hate About You (1999)     190.5
# 101 Dalmatians (1996)                 289.0
#                                       ...
# Zero Dark Thirty (2012)               287.5
# Zombieland (2009)                    1233.0
# Zoolander (2001)                     1137.0
# Zulu (1964)                            16.0
# eXistenZ (1999)                        85.0
# Name: rating, Length: 1554, dtype: float64

# %%
z=pd.DataFrame(x)

# %%
z.sort_values(by='rating',ascending=False).head(20)
# Out:
#                                                       rating
# title
# Pulp Fiction (1994)                                 233218.5
# Fight Club (1999)                                    50301.0
# Star Wars: Episode IV - A New Hope (1977)            27612.0
# Léon: The Professional (a.k.a. The Professional...   18707.5
# Eternal Sunshine of the Spotless Mind (2004)         18530.0
# 2001: A Space Odyssey (1968)                         17404.5
# Inception (2010)                                     15119.0
# Big Lebowski, The (1998)                             13312.0
# Donnie Darko (2001)                                  12586.0
# Forrest Gump (1994)                                  12330.0
# Braveheart (1995)                                     9555.0
# Star Wars: Episode V - The Empire Strikes Back ...    8895.0
# Memento (2000)                                        8521.5
# Lord of the Rings: The Return of the King, The ...    7620.0
# ...

# %%
ratings
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
movies
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %%
links
# Out:
#       movieId   imdbId    tmdbId
# 0           1   114709     862.0
# 1           2   113497    8844.0
# 2           3   113228   15602.0
# 3           4   114885   31357.0
# 4           5   113041   11862.0
# ...       ...      ...       ...
# 9737   193581  5476944  432131.0
# 9738   193583  5914996  445030.0
# 9739   193585  6397426  479308.0
# 9740   193587  8391976  483455.0
# 9741   193609   101726   37891.0
#
# [9742 rows x 3 columns]

# %%
tags
# Out:
#       userId  movieId               tag   timestamp
# 0          2    60756             funny  1445714994
# 1          2    60756   Highly quotable  1445714996
# 2          2    60756      will ferrell  1445714992
# 3          2    89774      Boxing story  1445715207
# 4          2    89774               MMA  1445715200
# ...      ...      ...               ...         ...
# 3678     606     7382         for katie  1171234019
# 3679     606     7936           austere  1173392334
# 3680     610     3265            gun fu  1493843984
# 3681     610     3265  heroic bloodshed  1493843978
# 3682     610   168248  Heroic Bloodshed  1493844270
#
# [3683 rows x 4 columns]

# %%
combined_3=pd.merge(combined_2,links,on='movieId')

# %%
combined_3
# Out:
#         movieId                           title  \
# 0             1                Toy Story (1995)
# 1             1                Toy Story (1995)
# 2             1                Toy Story (1995)
# 3             1                Toy Story (1995)
# 4             1                Toy Story (1995)
# ...         ...                             ...
# 233208   187595  Solo: A Star Wars Story (2018)
# 233209   193565       Gintama: The Movie (2010)
# 233210   193565       Gintama: The Movie (2010)
# 233211   193565       Gintama: The Movie (2010)
# 233212   193565       Gintama: The Movie (2010)
#
#                                              genres  userId_x  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy         1     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy         1     4.0
# 2       Adventure|Animation|Children|Comedy|Fantasy         1     4.0
# 3       Adventure|Animation|Children|Comedy|Fantasy         5     4.0
# ...

# %%
# mention the movie with the highest imdb rating

# %%
x = combined_3.groupby(['title', 'imdbId', 'movieId'])['rating'].sum().reset_index()

# %%
x.sort_values(by='rating',ascending=False)
# Out:
#                                                   title  imdbId  movieId  \
# 1078                                Pulp Fiction (1994)  110912      296
# 439                                   Fight Club (1999)  137523     2959
# 1299          Star Wars: Episode IV - A New Hope (1977)   76759      260
# 806   Léon: The Professional (a.k.a. The Professiona...  110413      293
# 402        Eternal Sunshine of the Spotless Mind (2004)  338013     7361
# ...                                                 ...     ...      ...
# 191                     Brandon Teena Story, The (1998)  144801     3281
# 915                               My Demon Lover (1987)   93589     4138
# 129                                     Begotten (1990)  101420    26717
# 972                             Oh, God! Book II (1980)   81268     5213
# 792                                    Losin' It (1983)   85868     4204
#
#         rating
# 1078  233218.5
# 439    50301.0
# 1299   27612.0
# 806    18707.5
# ...

# %%
# Mention the movieId of the "Sci-Fi" movie which has the highest IMDB rating.

# %%
combined_4=pd.merge(ratings,tags,on='movieId')

# %%
combined_4
# Out:
#         userId_x  movieId  rating  timestamp_x  userId_y               tag  \
# 0              1        1     4.0    964982703       336             pixar
# 1              1        1     4.0    964982703       474             pixar
# 2              1        1     4.0    964982703       567               fun
# 3              5        1     4.0    847434962       336             pixar
# 4              5        1     4.0    847434962       474             pixar
# ...          ...      ...     ...          ...       ...               ...
# 233208       599   176419     3.5   1516604655       567     uncomfortable
# 233209       599   176419     3.5   1516604655       567        unsettling
# 233210       594     7023     4.5   1108972356       474  In Netflix queue
# 233211       606     6107     4.0   1171324428       606      World War II
# 233212       606     6516     3.5   1171755910       474  In Netflix queue
#
#         timestamp_y
# 0        1139045764
# 1        1137206825
# ...

# %%
x=combined_4.groupby(['movieId','tag'])['rating'].sum()

# %%
x
# Out:
# movieId  tag
# 1        fun                843.0
#          pixar             1686.0
# 2        Robin Williams     377.5
#          fantasy            377.5
#          game               377.5
#                             ...
# 187595   star wars           19.5
# 193565   anime                3.5
#          comedy               3.5
#          gintama              3.5
#          remaster             3.5
# Name: rating, Length: 3558, dtype: float64

# %%
y=pd.DataFrame(x)

# %%
y.sort_values(by='rating',ascending=False).head()
# Out:
#                            rating
# movieId tag
# 260     classic sci-fi     3186.0
#         sci-fi             3186.0
# 2959    dark comedy        2794.5
# 296     Quentin Tarantino  2577.0
#         good dialogue      2577.0
